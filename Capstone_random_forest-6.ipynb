# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data cleaning</a></span></li><li><span><a href="#Basic-stats" data-toc-modified-id="Basic-stats-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Basic stats</a></span></li><li><span><a href="#Correlation-Heatmap" data-toc-modified-id="Correlation-Heatmap-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Correlation Heatmap</a></span></li><li><span><a href="#years-since-new-vs-depreciation-graph-and-stats" data-toc-modified-id="years-since-new-vs-depreciation-graph-and-stats-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>years since new vs depreciation graph and stats</a></span></li><li><span><a href="#Original-Price-and-depreciation-per-year" data-toc-modified-id="Original-Price-and-depreciation-per-year-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Original Price and depreciation per year</a></span></li><li><span><a href="#Year-distribution" data-toc-modified-id="Year-distribution-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Year distribution</a></span></li><li><span><a href="#Car-Models" data-toc-modified-id="Car-Models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Car Models</a></span></li><li><span><a href="#horsepower-vs-depreciation" data-toc-modified-id="horsepower-vs-depreciation-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>horsepower vs depreciation</a></span></li><li><span><a href="#Miles-per-gallon-vs-depreciation-boxplot" data-toc-modified-id="Miles-per-gallon-vs-depreciation-boxplot-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Miles per gallon vs depreciation boxplot</a></span></li><li><span><a href="#Number-Of-Features-Graph-and-Stats" data-toc-modified-id="Number-Of-Features-Graph-and-Stats-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Number Of Features Graph and Stats</a></span></li><li><span><a href="#Bluetooth-Wireless-Technology-Graph-and-Stats" data-toc-modified-id="Bluetooth-Wireless-Technology-Graph-and-Stats-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Bluetooth Wireless Technology Graph and Stats</a></span></li><li><span><a href="#Audible-Text-Messaging-Graph-and-Stats" data-toc-modified-id="Audible-Text-Messaging-Graph-and-Stats-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Audible Text Messaging Graph and Stats</a></span></li><li><span><a href="#Hands-Free-Phone-Graph-and-Stats" data-toc-modified-id="Hands-Free-Phone-Graph-and-Stats-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Hands Free Phone Graph and Stats</a></span></li><li><span><a href="#Internet-Access-Graph-and-Stats" data-toc-modified-id="Internet-Access-Graph-and-Stats-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Internet Access Graph and Stats</a></span></li><li><span><a href="#Smartphone-Interface--Graph-and-Stats" data-toc-modified-id="Smartphone-Interface--Graph-and-Stats-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Smartphone Interface  Graph and Stats</a></span></li><li><span><a href="#USB-Port-Graph-and-Stats" data-toc-modified-id="USB-Port-Graph-and-Stats-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>USB Port Graph and Stats</a></span></li><li><span><a href="#Voice-Recognition-System-Graph-and-Stats" data-toc-modified-id="Voice-Recognition-System-Graph-and-Stats-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Voice Recognition System Graph and Stats</a></span></li><li><span><a href="#Premium-Radio-Graph-and-Stats" data-toc-modified-id="Premium-Radio-Graph-and-Stats-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Premium Radio Graph and Stats</a></span></li><li><span><a href="#Bluetooth-Streaming-Audio-Graph-and-Stats" data-toc-modified-id="Bluetooth-Streaming-Audio-Graph-and-Stats-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Bluetooth Streaming Audio Graph and Stats</a></span></li><li><span><a href="#Expert-rating-graph-and-stats" data-toc-modified-id="Expert-rating-graph-and-stats-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Expert rating graph and stats</a></span></li><li><span><a href="#Consumer_Ratings-graph-and-stats" data-toc-modified-id="Consumer_Ratings-graph-and-stats-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Consumer_Ratings graph and stats</a></span></li><li><span><a href="#Creating-dummy-variables-for-saftey-ratings" data-toc-modified-id="Creating-dummy-variables-for-saftey-ratings-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Creating dummy variables for saftey ratings</a></span></li><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>Linear regression</a></span></li><li><span><a href="#Machine-learning:-Linear-Regression" data-toc-modified-id="Machine-learning:-Linear-Regression-24"><span class="toc-item-num">24&nbsp;&nbsp;</span>Machine learning: Linear Regression</a></span></li><li><span><a href="#Residuals" data-toc-modified-id="Residuals-25"><span class="toc-item-num">25&nbsp;&nbsp;</span>Residuals</a></span></li><li><span><a href="#Random-Forest-Regression" data-toc-modified-id="Random-Forest-Regression-26"><span class="toc-item-num">26&nbsp;&nbsp;</span>Random Forest Regression</a></span></li><li><span><a href="#Ridge-regression" data-toc-modified-id="Ridge-regression-27"><span class="toc-item-num">27&nbsp;&nbsp;</span>Ridge regression</a></span></li><li><span><a href="#GradientBoostingRegressor" data-toc-modified-id="GradientBoostingRegressor-28"><span class="toc-item-num">28&nbsp;&nbsp;</span>GradientBoostingRegressor</a></span></li></ul></div>

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
from scipy import stats  
from sklearn import linear_model
#import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
from sklearn.metrics import r2_score
import statsmodels.api as sm

# %% [markdown]
# # Data cleaning

# %%
KBB_df = pd.read_csv('KBB_df(6).csv')

# %%
del KBB_df['Unnamed: 0']
del KBB_df['Unnamed: 0.1']
del KBB_df['Year']
del KBB_df['Maker']
del KBB_df['Model']

# %%
KBB_df['depreciation'] = KBB_df['depreciation'].astype(float)

# %%
#valuecounts on safety rating then divide by len of the whole dataframe 
#as there is only three ratings for safety which are nothing, 4, and 5. Replace nothing with zero so the algorithm will work

# %%
KBB_df['SafetyRating'] = KBB_df['SafetyRating'].astype(str)

# %%
KBB_df['SafetyRating'] = KBB_df['SafetyRating'].astype(str)
KBB_df['SafetyRating'] = KBB_df['SafetyRating'].fillna('nothing')

# %%
KBB_df['Price_Used_USD'] = KBB_df['price in USD'].astype(float)
KBB_df['Price_New_USD'] = KBB_df['New_Price'].astype(float)
KBB_df['brand'] = KBB_df['brand'].astype(str)

# %%
KBB_df['depreciation'] = (KBB_df['Price_Used_USD']/KBB_df['Price_New_USD']).apply(lambda x: 1 - x)

# %%
KBB_df['depreciation per year'] = KBB_df['depreciation']/KBB_df['years since new']

# %%
KBB_df['expected_depreciation'] = KBB_df['years since new'].apply(lambda x: x*KBB_df['depreciation per year'].mean())

# %%
KBB_df.head()
# Out:
#     brand condition    fuel  kms driven  model  price in USD       price  \
# 0  toyota       new  petrol           1  yaris        323.52   50,000.00
# 1  toyota      used  petrol      100000  yaris        608.22   94,000.00
# 2  toyota      used     cng      100000     86       1164.67  180,000.00
# 3  toyota      used     cng          22     86       1261.73  195,000.00
# 4  toyota      used  petrol       66000  yaris        724.68  112,000.00
#
#    depreciation registered city     transaction type  ...  MP3 Player  \
# 0      0.979689         karachi                 cash  ...           1
# 1      0.958367          lahore                 cash  ...           1
# 2      0.956662         karachi                 cash  ...           0
# 3      0.953050         karachi                 cash  ...           0
# 4      0.946220       islamabad  installment/leasing  ...           1
#
#    Premium Radio  Satellite Radio Bluetooth Streaming Audio CD Player  \
# ...

# %%
KBB_df['MPG'] = KBB_df['MPG'].str.replace(r'MPG', '')
KBB_df['HP'] = KBB_df['HP'].str.replace(r'HP', '')

# %%
KBB_df['MPG'] = KBB_df['MPG'].astype(float)

# %%
KBB_df['HP'] = KBB_df['HP'].astype(float)

# %% [markdown]
# # Basic stats

# %%
KBB_df.corr()
# Out:
#                                  kms driven  price in USD  depreciation  \
# kms driven                         1.000000     -0.057753      0.077882
# price in USD                      -0.057753      1.000000     -0.747627
# depreciation                       0.077882     -0.747627      1.000000
# year                              -0.173623      0.248045     -0.392059
# years since new                    0.173623     -0.248045      0.392059
# New_Price                         -0.035956      0.659372     -0.150746
# MPG                               -0.072411      0.099919     -0.213750
# HP                                 0.006587      0.503113      0.018479
# Expert-Rating                     -0.008586      0.028461      0.123804
# Consumer-Rating                   -0.196013      0.100305     -0.173537
# Bluetooth Wireless Technology     -0.104151      0.310260     -0.310412
# Cruise Control                     0.071865     -0.031648      0.223299
# ...

# %%
KBB_df.describe()
# Out:
#          kms driven  price in USD  depreciation         year  years since new  \
# count  1.179000e+03   1179.000000   1179.000000  1179.000000      1179.000000
# mean   9.707247e+04  10089.146760      0.478879  2011.229008         7.770992
# std    3.318248e+05   5946.466843      0.190938     5.409713         5.409713
# min    1.000000e+00    323.520000      0.004554  1992.000000         1.000000
# 25%    3.600000e+04   6793.920000      0.351679  2008.000000         4.000000
# 50%    6.900000e+04   9705.600000      0.444640  2013.000000         6.000000
# 75%    9.999900e+04  12439.340000      0.566778  2015.000000        11.000000
# max    1.000000e+07  46586.870000      0.979689  2018.000000        27.000000
#
#            New_Price          MPG           HP  Expert-Rating  \
# count    1179.000000  1173.000000  1146.000000    1179.000000
# mean    18948.329941    36.714408   121.346422       4.046735
# std      7467.908851    10.548172    38.750546       0.598296
# ...

# %%
KBB_df[['kms driven', 'Price_Used_USD', 'years since new', 'MPG', 'HP', 'Expert-Rating', 'Consumer-Rating', 'SafetyRating', 'depreciation per year']].corr()
# Out:
#                        kms driven  Price_Used_USD  years since new       MPG  \
# kms driven               1.000000       -0.057753         0.173623 -0.072411
# Price_Used_USD          -0.057753        1.000000        -0.248045  0.099919
# years since new          0.173623       -0.248045         1.000000 -0.493294
# MPG                     -0.072411        0.099919        -0.493294  1.000000
# HP                       0.006587        0.503113         0.243327 -0.502200
# Expert-Rating           -0.008586        0.028461         0.340732 -0.109414
# Consumer-Rating         -0.196013        0.100305        -0.196710  0.472075
# depreciation per year   -0.077939       -0.271224        -0.415144  0.015790
#
#                              HP  Expert-Rating  Consumer-Rating  \
# kms driven             0.006587      -0.008586        -0.196013
# Price_Used_USD         0.503113       0.028461         0.100305
# years since new        0.243327       0.340732        -0.196710
# ...

# %%
KBB_df.shape
# Out:
# (1179, 46)

# %% [markdown]
# # Correlation Heatmap

# %% [markdown]
# Here is the heatmap to show all the positive and negative correlations

# %%
plt.figure(figsize= (46,46))
sns.heatmap(KBB_df.corr(), annot=True, cmap='coolwarm', annot_kws={"fontsize":20} )
plt.title('Heatmap')
sns.set(font_scale= 4) # font size 2
#depreciation and year
#depreciation and Bluetooth Wireless Technology 
#depreciation and Push-Buttion Engine Start
#depreciation and Remote Engine Start
#depreciation and Real-Time Traffic Information
#depreciation and 
#depreciation and 
#depreciation over time and across all cars 

#(6/22)expected depreciation (predict depreciation by year since new ), also make depreciation = 1- current depreciation 
# try log or expo model 
# plot the scatter 
# remove all rows where the new price is larger than the orignal price

# %%
plt.figure(figsize= (15,15))
sns.heatmap(KBB_df[['kms driven','Price_New_USD', 'Price_Used_USD', 'years since new', 'MPG', 'HP', 'Expert_Rating', 'Consumer_Rating', 'SafetyRating', 'depreciation per year', 'number_of_features']].corr(), annot=True, cmap='coolwarm', annot_kws={"fontsize":20} )
plt.title('Heatmap')
sns.set(font_scale= 4) # font size 2

#depreciation and year
#depreciation and Bluetooth Wireless Technology 
#depreciation and Push-Buttion Engine Start
#depreciation and Remote Engine Start
#depreciation and Real-Time Traffic Information
#depreciation and 
#depreciation and 
#depreciation over time and across all cars 

#(6/22)expected depreciation (predict depreciation by year since new ), also make depreciation = 1- current depreciation 
# try log or expo model 
# plot the scatter 
# remove all rows where the new price is larger than the orignal price
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-143c2105fd4d> in <module>
#       1 plt.figure(figsize= (15,15))
# ----> 2 sns.heatmap(KBB_df[['kms driven','Price_New_USD', 'Price_Used_USD', 'years since new', 'MPG', 'HP', 'Expert_Rating', 'Consumer_Rating', 'SafetyRating', 'depreciation per year', 'number_of_features']].corr(), annot=True, cmap='coolwarm', annot_kws={"fontsize":20} )
#       3 plt.title('Heatmap')
#       4 sns.set(font_scale= 4) # font size 2
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ...

# %%
sns.distplot(KBB_df['depreciation'])
plt.title('depreciation')
plt.show()
plt.figure()
plt.savefig('depreciation_univariate1.png')
#as we can see from the graph the bulk majority, the year of the models were 2015 and later

# %% [markdown]
# # years since new vs depreciation graph and stats

# %%
#rcParams['figure.figsize'] = [8.0, 6.0]
#rcParams['figure.dpi'] = 80
#rcParams['savefig.dpi'] = 100

#rcParams['font.size'] = 12
#rcParams['legend.fontsize'] = 'large'
#rcParams['figure.titlesize'] = 'medium'

# %%
import seaborn as sns
sns.scatterplot(data=KBB_df, x="years since new", y="depreciation")
# try stackexchange and reddit for the graphs

# %%
import seaborn as sns
sns.scatterplot(data=KBB_df, x="years since new", y="depreciation")
# try stackexchange and reddit for the graphs

# %%
KBB_df.plot.scatter(x='years since new', y='depreciation') # don't touch until you figure out what is going on with the graphs
plt.title('depreciation vs years since new')
plt.figure(figsize= (15,15))
#rcParams['figure.figsize'] = 30,30
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# first value is the corelation is 0.3920594237547733, pvalue is 1.3061064879820902e-44, since the pvalue is less than .05
# this gives strong evidence to reject the null hypothesis, the null hypthesis being that years since new affects the depreciation.
# Years since new(how old the car is) still might affect depreciation but clearly on its own it is not significant

# %%
#pearson stats
from scipy.stats.stats import pearsonr   
a = KBB_df['years since new']
b = KBB_df['depreciation']   
print (pearsonr(a,b))
# Out:
# (0.3920594237547733, 1.3061064879820902e-44)

# %% [markdown]
# # Original Price and depreciation per year

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_New_USD", y="depreciation per year", data=KBB_df)
plt.title('Price_New_USD vs depreciation',fontsize=30)
plt.savefig('Price_New_USD.png')
plt.figure(figsize=(30,30))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_New_USD",fontsize=30)
ax.set_ylabel("Depreciation",fontsize=30)
ax.set_xlim(0,60000)
plt.xticks(rotation = 45)
#hypothesis the cheaper cars will depreciate at a faster rate
#change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_New_USD", y="depreciation per year", data=KBB_df)
plt.title('Price New vs Depreciation',fontsize=20)
plt.savefig('Price_New_USD.png')
plt.figure(figsize=(40,40))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_New_USD",fontsize=20)
ax.set_ylabel("Depreciation",fontsize=20)
ax.set_xlim(0,60000)
plt.xticks(rotation = 45)
#hypothesis the cheaper cars will depreciate at a faster rate
#change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_New_USD", y="depreciation per year", data=KBB_df)
plt.title('Price_New_USD')
plt.savefig('Price_New_USD.png')
plt.figure(figsize=(20,20))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_New_USD",fontsize=30)
ax.set_ylabel("Depreciation",fontsize=30)
ax.set_xlim(0,60000)
plt.xticks(rotation = 45)
#hypothesis the cheaper cars will depreciate at a faster rate
#change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
KBB_df.plot.scatter(x="Price_New_USD", 
               y="depreciation per year")
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
KBB_df.plot(kind='scatter',x='Price_New_USD', y='depreciation per year', grid=True)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_New_USD", y="depreciation per year", data=KBB_df)
plt.title('New Price of Car vs. Depreciation',fontsize=30)
plt.savefig('Price_New_USD.png')
plt.figure(figsize=(50,50))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_New_USD",fontsize=30)
ax.set_ylabel("Depreciation",fontsize=30)
ax.set_xlim(0,60000)
plt.xticks(rotation = 45)
#hypothesis the cheaper cars will depreciate at a faster rate
#change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_New_USD", y="depreciation per year", data=KBB_df)
plt.title('Price_New_USD',fontsize=30)
plt.savefig('Price_New_USD.png')
plt.figure(figsize=(50,50))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_New_USD",fontsize=30)
ax.set_ylabel("Depreciation",fontsize=30)
ax.set_xlim(0,60000)
plt.xticks(rotation = 45)
#hypothesis the cheaper cars will depreciate at a faster rate
#change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]), <a list of 6 Text xticklabel objects>)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_New_USD", y="depreciation per year", data=KBB_df)
plt.title('Price_New_USD',fontsize=30)
plt.savefig('Price_New_USD.png')
plt.figure(figsize=(20,20))
ax.tick_params(labelsize=30)
ax.set_xlabel("Price_New_USD",fontsize=30)
ax.set_ylabel("Depreciation",fontsize=30)
ax.set_xlim(0,60000)
ax.xticks(rotation = 45)
#hypothesis the cheaper cars will depreciate at a faster rate
#change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
#try runing from the start
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-e8b021c3624b> in <module>
#      10 ax.set_ylabel("Depreciation",fontsize=30)
#      11 ax.set_xlim(0,60000)
# ---> 12 ax.xticks(rotation = 45)
#      13 #hypothesis the cheaper cars will depreciate at a faster rate
#      14 #change the title original price vs depreciation, change the labels size to become smaller and rotate them 45 degrees
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_Used_USD", y="depreciation per year", data=KBB_df)
plt.title('Price_Used_USD',fontsize=30)
plt.savefig('Price_Used_USD.png')
plt.figure(figsize=(20,20))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_Used_USD",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=30)
ax.set_xlim(0,60000)
#hypothesis the cheaper cars will depreciate at a faster rate
# Out:
# (0, 60000)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_Used_USD", y="depreciation per year", data=KBB_df)
plt.title('Price of a used car in USD vs Depreciation per year',fontsize=30)
plt.savefig('Price_Used_USD.png')
plt.figure(figsize=(40,40))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_Used_USD",fontsize=20)
ax.set_ylabel("depreciation per year",fontsize=20)
ax.set_xlim(0,60000)
#hypothesis the cheaper cars will depreciate at a faster rate
# Out:
# (0, 60000)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="Price_Used_USD", y="depreciation", data=KBB_df)
plt.title('Price_Used_USD',fontsize=30)
plt.savefig('Price_Used_USD.png')
plt.figure(figsize=(20,20))
ax.tick_params(labelsize=20)
ax.set_xlabel("Price_Used_USD",fontsize=30)
ax.set_ylabel("depreciation",fontsize=30)
ax.set_xlim(0,60000)
#hypothesis the cheaper cars will depreciate at a faster rate
# Out:
# (0, 60000)

# %% [markdown]
# first value is the corelation is -0.7476266602130743, pvalue is 1.8884558213409781e-211, since the pvalue is less than .05
# this gives strong evidence to reject the null hypothesis, the null hypthesis being that original price affects the depreciation.
# Years since new(how old the car is) still might affect depreciation but clearly on its own it is not significant

# %%
#pearson stats
#pearson
from scipy.stats.stats import pearsonr   
a = KBB_df['Price_Used_USD']
b = KBB_df['depreciation']   
print (pearsonr(a,b))
# Out:
# (-0.7476266602130743, 1.8884558213409781e-211)

# %% [markdown]
# # Year distribution

# %%
sns.distplot(KBB_df['year'])
plt.title('years')
plt.show()
plt.figure()
plt.savefig('years_1.png')
#as we can see from the graph the bulk majority, the year of the models were 2015 and later

# %%
mean = KBB_df["depreciation per year"].mean()
print(mean)
# Out:
# 0.10845332075533622

# %%
plt.hist(x=KBB_df['depreciation per year'])
plt.title('depreciation per year')
plt.show()
plt.figure()
plt.savefig('years_1.png')
#as we can see from the graph the bulk majority, the year of the models were 2015 and later

# %% [markdown]
# # Car Models

# %%
KBB_df['model'].value_counts()
# Out:
# yaris       433
# prius-c     276
# prius       155
# accord       79
# sentra       68
# gx           47
# fit          37
# camry        16
# mirage       13
# sportage     12
# insight       9
# 86            7
# accent        4
# rav4          3
# cr-v          3
# spark         3
# a3            3
# a5            2
# sonata        2
# a4            2
# q7            2
# elantra       2
# i8            1
# Name: model, dtype: int64

# %%
KBB_df2 = KBB_df[KBB_df['model'].isin(['yaris', 'prius-c', 'prius', 'accord', 'sentra', 'gx', 'fit'])]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
ax = sns.boxplot(x="model", y="depreciation",showfliers=False, 
                 data=KBB_df2, palette="Set3")
plt.axhline(0.10845332075533622, 0, color="Red")
plt.title('Depreciation By Top Models',fontsize=30)

ax.set_xlabel("model",fontsize=20)
ax.set_ylabel("Depreciation",fontsize=20)
ax.tick_params(labelsize=20)
plt.savefig('model')
#keep the outliers

# %%
x1 = KBB_df2["model"]
y1 = KBB_df2["SafetyRating_b"]

#separate the models into different groups coresponding depreciation 
#might have problems because different size in the groups
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SafetyRating_b'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-47d9a32e00f6> in <module>
#       1 x1 = KBB_df2["model"]
# ...

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
from statsmodels.base.model import Model

print(pairwise_tukeyhsd(KBB_df2['depreciation'],
                            KBB_df2['model']))
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1  group2 meandiff p-adj   lower   upper  reject
# ------------------------------------------------------
#  accord     fit   -0.264  0.001  -0.357 -0.1709   True
#  accord      gx  -0.2985  0.001 -0.3845 -0.2125   True
#  accord   prius  -0.1696  0.001 -0.2342 -0.1051   True
#  accord prius-c  -0.2107  0.001 -0.2703 -0.1511   True
#  accord  sentra   0.1388  0.001  0.0615   0.216   True
#  accord   yaris  -0.1735  0.001 -0.2307 -0.1164   True
#     fit      gx  -0.0345    0.9 -0.1372  0.0681  False
#     fit   prius   0.0944 0.0196  0.0089  0.1798   True
#     fit prius-c   0.0533 0.4663 -0.0285   0.135  False
#     fit  sentra   0.4028  0.001  0.3074  0.4982   True
#     fit   yaris   0.0905 0.0151  0.0105  0.1704   True
#      gx   prius   0.1289  0.001  0.0511  0.2066   True
#      gx prius-c   0.0878 0.0082  0.0141  0.1615   True
#      gx  sentra   0.4373  0.001  0.3487  0.5259   True
# ...

# %% [markdown]
# # horsepower vs depreciation

# %%
#add horsepower vs depreciation
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="HP", y="depreciation", data=KBB_df)
plt.title('Horsepower')
ax.set_xlabel("HP",fontsize=20)
ax.set_ylabel("depreciation per year",fontsize=20)
ax.tick_params(labelsize=20)
plt.title('Horse Power',fontsize=20)
plt.savefig('scatter_1.png')
#hypothesis the cheaper cars will depreciate at a faster rate

# %%
#add horsepower vs depreciation
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="HP", y="depreciation", data=KBB_df)
plt.title('Horsepower')
ax.set_xlabel("HP",fontsize=20)
ax.set_ylabel("depreciation per year",fontsize=20)
ax.tick_params(labelsize=20)
plt.title('Horse Power',fontsize=50)
plt.savefig('scatter_1.png')
#hypothesis the cheaper cars will depreciate at a faster rate

# %%
#add horsepower vs depreciation
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="HP", y="depreciation", data=KBB_df)
#plt.title('Horsepower vs. Depreciation')
ax.set_xlabel("HP",fontsize=20)
ax.set_ylabel("depreciation",fontsize=20)
ax.tick_params(labelsize=20)
plt.title('Horsepower vs. Depreciation',fontsize=30)
plt.savefig('scatter_1.png')
#hypothesis the cheaper cars will depreciate at a faster rate

# %%
#add horsepower vs depreciation
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="HP", y="depreciation", data=KBB_df)
plt.title('Horsepower')
ax.set_xlabel("HP",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
ax.tick_params(labelsize=20)
plt.title('Horse Power',fontsize=50)
plt.savefig('scatter_1.png')
#hypothesis the cheaper cars will depreciate at a faster rate

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="MPG", y="depreciation", data=KBB_df)
ax.set_xlabel("MPG",fontsize=20)
ax.set_ylabel("depreciation per year",fontsize=20)
ax.tick_params(labelsize=20)
plt.title('MPG vs depreciation',fontsize=30)
plt.savefig('scatter_MPG.png')
#hypothesis the cheaper cars will depreciate at a faster rate

# %%
KBB_df.plot.scatter(x='MPG',
                      y='depreciation',
                      c='DarkBlue', figsize = (5,5))
#add fig size 5,5 for the scatter plots
#bucket the mpg , box plot

# %%
KBB_df['depreciation'].value_counts(0)
# Out:
# 0.344051    10
# 0.263915     9
# 0.359306     9
# 0.374561     8
# 0.469955     7
#             ..
# 0.320480     1
# 0.756733     1
# 0.344755     1
# 0.340414     1
# 0.438806     1
# Name: depreciation, Length: 801, dtype: int64

# %%
KBB_df['depreciation'].isnull().values.any()
# Out:
# False

# %%
KBB_df['HP'].isnull().values.any()
# Out:
# True

# %%
KBB_df['MPG'].isnull().sum().sum()
# Out:
# 6

# %%
KBB_df['registered city'].isnull().sum().sum()
# Out:
# 227

# %%
KBB_df['HP'].isnull().sum().sum()
# Out:
# 33

# %%
nan_values = KBB_df.isna()
nan_columns = nan_values.any()

columns_with_nan = KBB_df.columns[nan_columns].tolist()
print(columns_with_nan)
# Out:
# ['registered city', 'MPG', 'HP']

# %%
KBB_df = KBB_df.fillna(0)

# %%
#pearson
from scipy.stats.stats import pearsonr   
a = KBB_df['HP']
b = KBB_df['depreciation']   
print (pearsonr(a,b))

#first value is the corelation is -0.03497611363371208, pvalue is 0.23011874876637908, since the pvalue is less than
# Out:
# (-0.03497611363371208, 0.23011874876637908)

# %%
KBB_df['MPG'].value_counts()
# Out:
# 50.0    367
# 32.0    268
# 31.0    176
# 25.0     41
# 29.0     35
# 27.0     31
# 46.0     30
# 28.0     26
# 16.0     23
# 23.0     21
# 47.0     19
# 15.0     16
# 24.0     15
# 36.0     15
# 37.0     10
# 52.0      9
# 30.0      9
# 21.0      9
# 17.0      9
# 18.0      8
# 42.0      7
# 35.0      6
# 33.0      6
# 0.0       6
# 26.0      5
# 22.0      3
# 34.0      3
# 41.0      3
# 39.0      2
# 20.0      1
# Name: MPG, dtype: int64

# %%
KBB_df.fillna(0, inplace= True)

# %%
KBB_df['MPG'] = KBB_df['MPG'].astype(float)

# %%
#add mpg vs depreciation
custom_bucket_array = np.linspace(0, 52, 5)

KBB_df['MPG'] = pd.cut(KBB_df['MPG'], custom_bucket_array)
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
#tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="MPG", y="depreciation", data=KBB_df)
custom_bucket_array = np.linspace(0, 52, 5)

plt.title('Miles per gallon',fontsize=30)
ax.set_xlabel("MPG",fontsize=30)
ax.set_ylabel("depreciation ",fontsize=20)
plt.savefig('scatter_3.png')
#hypothesis the cheaper cars will depreciate at a faster rate 
#order the x axis # convert mpg into an int or float
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-b16224a89ef4> in <module>
#       6 import matplotlib.pyplot as plt
#       7 #tips = sns.load_dataset("tips")
# ----> 8 ax = sns.scatterplot(x="MPG", y="depreciation", data=KBB_df)
#       9 custom_bucket_array = np.linspace(0, 52, 5)
#      10
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1406         ax = plt.gca()
#    1407
# -> 1408     p.plot(ax, kwargs)
#    1409
#    1410     return ax
#
# ~\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     953
#     954         args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# ...

# %% [markdown]
# # Miles per gallon vs depreciation boxplot

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x="MPG", y="depreciation", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.title('Miles Per Gallon')
plt.axhline(0.10845332075533622, 0, color="Red")
custom_bucket_array = np.linspace(2.2, 4.8, 5)

KBB_df['Expert_Rating_d'] = pd.cut(KBB_df['Expert_Rating'], custom_bucket_array)
ax.set_xlabel("MPG",fontsize=30)
ax.set_ylabel("depreciation per",fontsize=30)
plt.title('MPG',fontsize=30)
#plt.savefig('Bluetooth Wireless Technology.png')
#null hypothesis is that the cars with more features will depreciate at a slower rate

# do the buckets by 5s
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Expert_Rating'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-9d1d6eb79db0> in <module>
# ...

# %%
custom_bucket_array = np.linspace(0, 52, 5)

KBB_df['MPG'] = pd.cut(KBB_df['MPG'], custom_bucket_array)



plt.figure(figsize=(10,10))
ax = sns.boxplot(x="MPG", y="depreciation", showfliers = False,
                 data=KBB_df, palette="Set3")

plt.title('number of features')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("MPG",fontsize=30)
ax.set_ylabel("depreciation per",fontsize=30)
plt.title('MPG',fontsize=30)
#plt.savefig('Bluetooth Wireless Technology.png')
#null hypothesis is that the cars with more features will depreciate at a slower rate

# do the buckets by 5s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-a8a99f31527d> in <module>
#       1 custom_bucket_array = np.linspace(0, 52, 5)
#       2
# ----> 3 KBB_df['MPG'] = pd.cut(KBB_df['MPG'], custom_bucket_array)
#       4
#       5
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     263         include_lowest=include_lowest,
#     264         dtype=dtype,
# --> 265         duplicates=duplicates,
#     266     )
#     267
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates)
#     386
#     387     side = "left" if right else "right"
# --> 388     ids = ensure_int64(bins.searchsorted(x, side=side))
#     389
#     390     if include_lowest:
#
# ...

# %% [markdown]
# first value is the corelation is -0.20340775426076624, pvalue is 1.7795338384446617e-12, since the pvalue is less than .05
# this gives strong evidence to reject the null hypothesis, the null hypthesis being cars with a higher MPG will depreciate slower
# MPG still might affect depreciation but clearly on its own it is not significant

# %%
from scipy.stats.stats import pearsonr   
a = KBB_df['MPG']
b = KBB_df['depreciation']   
print (pearsonr(a,b))

#first value is the corelation is -0.20340775426076624, pvalue is 1.7795338384446617e-12, since the pvalue is less than .05
#this gives strong evidence to reject the null hypothesis, the null hypthesis being cars with a higher MPG will depreciate slower 
#MPG still might affect depreciation but clearly on its own it is not significant
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-03a4c398ad72> in <module>
#       2 a = KBB_df['MPG']
#       3 b = KBB_df['depreciation']
# ----> 4 print (pearsonr(a,b))
#       5
#       6 #first value is the corelation is -0.20340775426076624, pvalue is 1.7795338384446617e-12, since the pvalue is less than .05
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3517         return dtype(np.sign(x[1] - x[0])*np.sign(y[1] - y[0])), 1.0
#    3518
# -> 3519     xmean = x.mean(dtype=dtype)
#    3520     ymean = y.mean(dtype=dtype)
#    3521
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#     149             is_float16_result = True
#     150
# --> 151     ret = umr_sum(arr, axis, dtype, out, keepdims)
#     152     if isinstance(ret, mu.ndarray):
#     153         ret = um.true_divide(
# ...

# %% [markdown]
# # Number Of Features Graph and Stats

# %%
KBB_df['number_of_features'] = KBB_df['Audible Text Messaging']+KBB_df['Bluetooth Wireless Technology']+KBB_df['Hands Free Phone']+KBB_df['Internet Access']+KBB_df['Smartphone Interface']+KBB_df['USB Port']+KBB_df['Voice Recognition System']+KBB_df['Premium Radio']+KBB_df['Bluetooth Streaming Audio']

# %%
KBB_df['number_of_features_b'] = KBB_df['number_of_features']

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x="number_of_features", y="depreciation per year", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.title('number of features')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("number_of_features",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Number of features',fontsize=50)
#plt.savefig('Bluetooth Wireless Technology.png')
#null hypothesis is that the cars with more features will depreciate at a slower rate
# Out:
# Text(0.5, 1.0, 'Number of features')

# %%
KBB_df.number_of_features[KBB_df.number_of_features <= (4)] = 0
KBB_df.number_of_features[KBB_df.number_of_features > (4)] = 1
# Out:
# C:\Users\adame\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\adame\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from scipy import stats

# %%
grouped3 = KBB_df.groupby('number_of_features')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['number_of_features'] == 0]
sample_B = KBB_df[KBB_df['number_of_features'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-14.71789558550806, pvalue=3.9115053146065395e-45)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant,
# The null hypothesis was that cars more than 4 features would deprecieate slower

# %% [markdown]
# # Bluetooth Wireless Technology Graph and Stats

# %%
KBB_df['Bluetooth Wireless Technology_b'] = KBB_df['Bluetooth Wireless Technology']

# %%
KBB_df['Bluetooth Wireless Technology_c'] = KBB_df['Bluetooth Wireless Technology']

KBB_df['Bluetooth Wireless Technology_c'] = KBB_df['Bluetooth Wireless Technology_c'].astype(str)

KBB_df["Bluetooth Wireless Technology_c"].replace({"0": "no", "1": "yes"}, inplace=True)

plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Bluetooth Wireless Technology", y="depreciation per year", hue="Bluetooth Wireless Technology_c", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.title('Bluetooth Wireless Technology')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Bluetooth Wireless Technology",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Bluetooth Wireless Technology',fontsize=50)
plt.savefig('Bluetooth Wireless Technology_2.png')

# %%
KBB_df.plot.scatter(x='Bluetooth Wireless Technology', y='depreciation per year')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
grouped3 = KBB_df.groupby('Bluetooth Wireless Technology')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Bluetooth Wireless Technology'] == 0]
sample_B = KBB_df[KBB_df['Bluetooth Wireless Technology'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-10.650201883687227, pvalue=2.3773017701903436e-25)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with bluetooth wireless would deprecieate slower

# %% [markdown]
# # Audible Text Messaging Graph and Stats

# %%
KBB_df['Audible Text Messaging_b'] = KBB_df['Audible Text Messaging']

# %%
KBB_df['Audible Text Messaging_c'] = KBB_df['Audible Text Messaging']

KBB_df['Audible Text Messaging_c'] = KBB_df['Audible Text Messaging_c'].astype(str)

KBB_df["Audible Text Messaging_c"].replace({"0": "no", "1": "yes"}, inplace=True)

plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Audible Text Messaging", y="depreciation per year", hue="Audible Text Messaging_c", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.title('Audible Text Messaging')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Audible Text Messaging",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Audible Text Messaging',fontsize=50)
plt.savefig('Audible Text Messaging.png')

# %%
KBB_df.plot.scatter(x='Audible Text Messaging', y='depreciation per year')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
grouped3 = KBB_df.groupby('Audible Text Messaging_b')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Audible Text Messaging_b'] == 0]
sample_B = KBB_df[KBB_df['Audible Text Messaging_b'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-6.99621941187798, pvalue=4.402742080582445e-12)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with audible text messages would deprecieate slower

# %% [markdown]
# # Hands Free Phone Graph and Stats

# %%
KBB_df['Hands Free Phone_b'] = KBB_df['Hands Free Phone']

# %%
KBB_df['Hands Free Phone_c'] = KBB_df['Hands Free Phone']

KBB_df['Hands Free Phone_c'] = KBB_df['Hands Free Phone_c'].astype(str)

KBB_df["Hands Free Phone_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Hands Free Phone", y="depreciation per year", hue="Hands Free Phone_c",showfliers = False,
                 data=KBB_df, palette="Set3")
plt.axhline(0.10845332075533622, 0, color="Red")
plt.savefig('Hands Free Phone.png')
ax.set_xlabel("Hands Free Phone",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Hands Free Phone',fontsize=50)

savefig('sample.png')
import os
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-0d9cb3303545> in <module>
#      15 plt.title('Hands Free Phone',fontsize=50)
#      16
# ---> 17 savefig('sample.png')
#      18 import os
#      19 print(os.getcwd())
#
# NameError: name 'savefig' is not defined

# %%
grouped3 = KBB_df.groupby('Hands Free Phone_b')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Hands Free Phone_b'] == 0]
sample_B = KBB_df[KBB_df['Hands Free Phone_b'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-8.172106836896937, pvalue=7.760783819545e-16)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with hands free phone would deprecieate slower

# %% [markdown]
# # Internet Access Graph and Stats

# %%
KBB_df['Internet Access_b'] = KBB_df['Internet Access']

# %%
KBB_df['Internet Access_c'] = KBB_df['Internet Access']

KBB_df['Internet Access_c'] = KBB_df['Internet Access_c'].astype(str)

KBB_df["Internet Access_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Internet Access", y="depreciation per year", hue="Internet Access_c", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Internet Access",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Internet Access',fontsize=50)
plt.savefig('Internet Access.png')

# %%
grouped3 = KBB_df.groupby('Internet Access')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Internet Access'] == 0]
sample_B = KBB_df[KBB_df['Internet Access'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-10.130780954572355, pvalue=3.487066742649946e-23)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with hands free phone would deprecieate slower

# %% [markdown]
# # Smartphone Interface  Graph and Stats

# %%
KBB_df['Smartphone Interface_b'] = KBB_df['Smartphone Interface']

# %%
KBB_df['Smartphone Interface_c'] = KBB_df['Smartphone Interface']

KBB_df['Smartphone Interface_c'] = KBB_df['Smartphone Interface_c'].astype(str)

KBB_df["Smartphone Interface_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Smartphone Interface", y="depreciation per year", hue="Smartphone Interface_c", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Smartphone Interface",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Smartphone Interface',fontsize=50)
plt.savefig('Smartphone Interface.png')

# %%
grouped3 = KBB_df.groupby('Smartphone Interface')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Smartphone Interface'] == 0]
sample_B = KBB_df[KBB_df['Smartphone Interface'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-10.634221828433065, pvalue=2.7799856922757625e-25)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with Smartphone Interface would deprecieate slower

# %% [markdown]
# # USB Port Graph and Stats

# %%
KBB_df['USB Port_b'] = KBB_df['USB Port']

# %%
KBB_df['USB Port_c'] = KBB_df['USB Port']

KBB_df['USB Port_c'] = KBB_df['USB Port_c'].astype(str)

KBB_df["USB Port_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="USB Port", y="depreciation per year", hue="USB Port_c", showfliers = False,
                 data=KBB_df, palette="Set3")
plt.title('USB Port')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("USB Port",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('USB Port',fontsize=50)
plt.savefig('USB Port.png')

# %%
grouped3 = KBB_df.groupby('USB Port')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['USB Port'] == 0]
sample_B = KBB_df[KBB_df['USB Port'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-10.939342736887385, pvalue=1.3561124186818884e-26)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with USB Port would deprecieate slower

# %% [markdown]
# # Voice Recognition System Graph and Stats

# %%
KBB_df['Voice Recognition System_b'] = KBB_df['Voice Recognition System']

# %%
KBB_df['Voice Recognition System_c'] = KBB_df['Voice Recognition System']

KBB_df['Voice Recognition System_c'] = KBB_df['Voice Recognition System_c'].astype(str)

KBB_df["Voice Recognition System_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Voice Recognition System", y="depreciation per year", hue="Voice Recognition System_c",
                 data=KBB_df, palette="Set3")
plt.title('Voice Recognition System')
plt.axhline(0.10845332075533622, 0, color="Red")
plt.title('Premium Radio')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Voice Recognition System",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Voice Recognition System',fontsize=50)
plt.axhline(0.10845332075533622, 0, color="Red")
ax.tick_params(labelsize=20)
plt.savefig('Voice Recognition System.png')

# %%
grouped3 = KBB_df.groupby('Voice Recognition System')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Voice Recognition System'] == 0]
sample_B = KBB_df[KBB_df['Voice Recognition System'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-8.98035338830338, pvalue=1.0456738289139663e-18)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with voice recognition would deprecieate slower

# %% [markdown]
# # Premium Radio Graph and Stats

# %%
KBB_df['Premium Radio_b'] = KBB_df['Premium Radio']

# %%
KBB_df['Premium Radio_c'] = KBB_df['Premium Radio']

KBB_df['Premium Radio_c'] = KBB_df['Premium Radio_c'].astype(str)

KBB_df["Premium Radio_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Premium Radio", y="depreciation", hue="Premium Radio_c",
                 data=KBB_df, palette="Set3")
plt.title('Premium Radio')
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Premium Radio",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Premium Radio',fontsize=50)
plt.axhline(0.10845332075533622, 0, color="Red")
ax.tick_params(labelsize=20)
plt.savefig('Premium Radio.png')

# %%
grouped3 = KBB_df.groupby('Premium Radio')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Premium Radio'] == 0]
sample_B = KBB_df[KBB_df['Premium Radio'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation'], sample_B['depreciation'])
print(t_result)
# Out:
# Ttest_indResult(statistic=3.707390452258404, pvalue=0.00021915188819432975)

# %% [markdown]
# Cars with preium radio depreciate faster and that result is statistically significant

# %% [markdown]
# # Bluetooth Streaming Audio Graph and Stats

# %%
KBB_df['Bluetooth Streaming Audio_b'] = KBB_df['Bluetooth Streaming Audio']

# %%
KBB_df['Bluetooth Streaming Audio_c'] = KBB_df['Bluetooth Streaming Audio']

KBB_df['Bluetooth Streaming Audio_c'] = KBB_df['Bluetooth Streaming Audio_c'].astype(str)

KBB_df["Bluetooth Streaming Audio_c"].replace({"0": "no", "1": "yes"}, inplace=True)


plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Bluetooth Streaming Audio", y="depreciation per year", hue="Bluetooth Streaming Audio_c",
                 data=KBB_df, palette="Set3")
plt.axhline(0.10845332075533622, 0, color="Red")
ax.set_xlabel("Bluetooth Streaming Audio_c",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Bluetooth Streaming Audio',fontsize=50)
plt.axhline(0.10845332075533622, 0, color="Red")
ax.tick_params(labelsize=20)
plt.savefig('Bluetooth_Streaming_Audio.png')

# %%
grouped3 = KBB_df.groupby('Bluetooth Streaming Audio')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df[KBB_df['Bluetooth Streaming Audio'] == 0]
sample_B = KBB_df[KBB_df['Bluetooth Streaming Audio'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation'], sample_B['depreciation'])
print(t_result)
# Out:
# Ttest_indResult(statistic=10.197578094411574, pvalue=1.8570472736293212e-23)

# %% [markdown]
# the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with blue tooth streaming audio would deprecieate slower

# %% [markdown]
# # Expert rating graph and stats

# %%
KBB_df= KBB_df.rename(columns={'Expert-Rating': 'Expert_Rating'})

# %%
KBB_df['Expert_Rating_b']= KBB_df['Expert_Rating']

# %%
#do boxplot for safety/consumer/expert ratings
KBB_df['Expert_Rating_c'] = KBB_df['Expert_Rating']

KBB_df['Expert_Rating_c'] = KBB_df['Expert_Rating_c'].astype(str)

KBB_df["Expert_Rating_c"].replace({"0": "no", "1": "yes"}, inplace=True)



plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Expert_Rating", y="depreciation per year", 
                 data=KBB_df, palette="Set3")
#ax.axes.set_title("Expert_Rating",fontsize=50)
ax.set_xlabel("Expert_Rating",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Expert_Rating',fontsize=50)
plt.axhline(0.10845332075533622, 0, color="Red")
ax.tick_params(labelsize=20)

xticks=[0,2.5,5]
#plt.savefig('Expert-Rating.png')

# %%
ax = sns.boxplot(x="Expert_Rating", y="depreciation per year", 
                 data=KBB_df, palette="Set3")
#ax.axes.set_title("Expert_Rating",fontsize=50)
ax.set_xlabel("Expert_Rating",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Expert_Rating',fontsize=50)
plt.axhline(0.10845332075533622, 0, color="Red")
ax.tick_params(labelsize=20)

xticks=[0,2.5,5]
#plt.savefig('Expert-Rating.png')

# %%
import pandas as pd
import numpy as np
custom_bucket_array = np.linspace(2.2, 4.8, 5)

KBB_df['Expert_Rating_d'] = pd.cut(KBB_df['Expert_Rating'], custom_bucket_array)

plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Expert_Rating_d", y="depreciation per year", showfliers=False, 
                 data=KBB_df, palette="Set3")
#ax.axes.set_title("Expert_Rating",fontsize=50)
ax.set_xlabel("Expert_Rating",fontsize=30)
ax.set_ylabel("depreciation per year",fontsize=20)
plt.title('Expert_Rating vs depreciation',fontsize=30)
plt.axhline(0.10845332075533622, 0, color="Red")
ax.tick_params(labelsize=20)
#g
xticks=[0,2.5,5]
#plt.savefig('Expert-Rating.png')

# %%
#pearson stats
from scipy.stats.stats import pearsonr   
a = KBB_df['Expert_Rating']
b = KBB_df['depreciation']   
print (pearsonr(a,b))
# Out:
# (0.12380386069872037, 2.0179061839621092e-05)

# %% [markdown]
# first value is the corelation is 0.12380386069872037, pvalue is 2.0179061839621092e-05, the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with an expert rating above 3.7 would depreciate at a slower rate

# %% [markdown]
# # Consumer_Ratings graph and stats

# %%
KBB_df= KBB_df.rename(columns={'Consumer-Rating': 'Consumer_Rating'})

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Consumer_Rating", y="depreciation per year", 
                 data=KBB_df, palette="Set3")
plt.title('Consumer-Rating')
plt.axhline(0.10845332075533622, 0, color="Red")
plt.savefig('Consumer-Rating.png')

# %%
# Out:
# C:\Users\adame\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
import pandas as pd
import numpy as np

KBB_df['Consumer_Rating_d'] = pd.cut(KBB_df['Consumer_Rating'], 4)
#change the bucket to start at 4.2
plt.figure(figsize=(10,10))
ax = sns.boxplot(x="Consumer_Rating_d", y="depreciation per year", 
                 data=KBB_df, palette="Set3")
plt.title('Consumer-Rating vs depreciation')
plt.axhline(0.10845332075533622, 0, color="Red")
plt.savefig('Consumer-Rating.png')

# %%
KBB_df['Consumer_Rating'] = KBB_df['Consumer_Rating'].astype(float)

# %%
#pearson stats
from scipy.stats.stats import pearsonr   
a = KBB_df['Consumer_Rating']
b = KBB_df['depreciation']   
print (pearsonr(a,b))

#first value is the corelation is -0.1735374587285996, pvalue is 1.9985596118595722e-09, since the pvalue is less than
# Out:
# (-0.1735374587285996, 1.9985596118595722e-09)

# %% [markdown]
# first value is the corelation is -0.1735374587285996, pvalue is 1.9985596118595722e-09, the pvalue is below .05 so we can reason that the null hypothesis is not statistically significant ,
# The null hypothesis was that cars with an consumer rating above 4.3 would depreciate at a slower rate

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Creating dummy variables for saftey ratings

# %%
KBB_df['SafetyRating_b']= KBB_df['SafetyRating']

# %%
KBB_df['SafetyRating'] = KBB_df['SafetyRating'].astype(str)
KBB_df['SafetyRating'] = KBB_df['SafetyRating'].fillna('')

# %%
KBB_df['SafetyRating'] = KBB_df['SafetyRating'].replace('nan','nothing')

# %%
KBB_df3 = pd.get_dummies(KBB_df, columns=['SafetyRating'])

# %%
KBB_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179 entries, 0 to 1178
# Data columns (total 71 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   brand                            1179 non-null   object
#  1   condition                        1179 non-null   object
#  2   fuel                             1179 non-null   object
#  3   kms driven                       1179 non-null   int64
#  4   model                            1179 non-null   object
#  5   price in USD                     1179 non-null   float64
#  6   price                            1179 non-null   object
#  7   depreciation                     1179 non-null   float64
#  8   registered city                  952 non-null    object
#  9   transaction type                 1179 non-null   object
#  10  year                             1179 non-null   int64
#  11  years since new                  1179 non-null   int64
# ...

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(x="SafetyRating", y="depreciation per year", 
                 data=KBB_df, palette="Set3")
plt.title('SafetyRating')
plt.axhline(0.10845332075533622, 0, color="Red")
plt.savefig('SafetyRating.png')

#change categories into strings, after runing the graphs then I will make dummies

# %%
# nothing vs 4.0
grouped3 = KBB_df3.groupby('SafetyRating_4.0')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df3[KBB_df3['SafetyRating_4.0'] == 0]
sample_B = KBB_df3[KBB_df3['SafetyRating_4.0'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-1.3077232654076838, pvalue=0.19122255482391193)

# %%
# nothing vs 4.0
grouped3 = KBB_df3.groupby('SafetyRating_5.0')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df3[KBB_df3['SafetyRating_5.0'] == 0]
sample_B = KBB_df3[KBB_df3['SafetyRating_5.0'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=-4.84412929258427, pvalue=1.4412023850027835e-06)

# %%
grouped3 = KBB_df3.groupby('SafetyRating_nothing')
#n0 = grouped3.count().loc[0][0]
#n1 = grouped3.count().loc[1][0]

sample_A = KBB_df3[KBB_df3['SafetyRating_nothing'] == 0]
sample_B = KBB_df3[KBB_df3['SafetyRating_nothing'] == 1]

#passing list of the depreciation of everything with bluetooth and everything without bluetooth 

t_result = stats.ttest_ind(sample_A['depreciation per year'], sample_B['depreciation per year'])
print(t_result)
# Out:
# Ttest_indResult(statistic=3.780042755290444, pvalue=0.00016466248130340085)

# %% [markdown]
# #first value is the corelation is -0.23465831048933028, pvalue is 3.2665185525752527e-16, the pvalue is below .05 so we can #reason that the null hypothesis is not statistically significant ,
# #The null hypothesis was that cars with an consumer rating above 0 would depreciate at a slower rate , <ignore this>

# %% [markdown]
# # Linear regression

# %%
ax = sns.regplot(x="years since new", y="depreciation", data=KBB_df) #Plot data and a linear regression
plt.savefig('Linear_regression_expected_depreciation.png')
 #y="sepal_length", model fit
 #data=KBB_df,
 #ax=ax)

# %%
#pearson stats
from scipy.stats.stats import pearsonr   
a = KBB_df['years since new']
b = KBB_df['depreciation']   
print (pearsonr(a,b))

#can accept given the p value is so small
# Out:
# (0.3920594237547733, 1.3061064879820902e-44)

# %%
ax = sns.regplot(x="years since new", y="depreciation per year", data=KBB_df) #Plot data and a linear regression
plt.savefig('Linear_regression_expected_depreciation.png')
 #y="sepal_length", model fit
 #data=KBB_df,
 #ax=ax)
# depreicates less and less per year

# %%
plt.figure(figsize=(5,5))
ax = sns.regplot(x="depreciation", y="years since new", data=KBB_df)
plt.savefig('Linear_regression_depreciation.png')
#linear regression with depreciation

# %%
ax = sns.regplot(x="years since new", y="depreciation", data=KBB_df)
plt.savefig('Linear_regression_depreciation.png')

# %%
g = sns.lmplot(x="Price_New_USD", y="depreciation", data= KBB_df)
g.set(xlim=(0, 60000))
g.set(ylim=(-.1, None))
#so cars the cars under 3000 are so scattered that the correlation doesn't matter that much 
#drop car which is over 150,000

# %%
sns.regplot(x="Price_New_USD", y="depreciation", data=KBB_df)

# %% [markdown]
# # Machine learning: Linear Regression

# %%
import numpy as np
from sklearn import linear_model

# %%
KBB_df3 = KBB_df3.fillna(0)

# %%
from sklearn import linear_model
import statsmodels.api as sm

# %%
reg = linear_model.LinearRegression()

# %%
KBB_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1179 entries, 0 to 1178
# Data columns (total 71 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   brand                            1179 non-null   object
#  1   condition                        1179 non-null   object
#  2   fuel                             1179 non-null   object
#  3   kms driven                       1179 non-null   int64
#  4   model                            1179 non-null   object
#  5   price in USD                     1179 non-null   float64
#  6   price                            1179 non-null   object
#  7   depreciation                     1179 non-null   float64
#  8   registered city                  1179 non-null   object
#  9   transaction type                 1179 non-null   object
#  10  year                             1179 non-null   int64
#  11  years since new                  1179 non-null   int64
# ...

# %%
reg.fit(KBB_df3[['HP', 'SafetyRating_4.0','SafetyRating_5.0','SafetyRating_nothing', 'Consumer_Rating', 'Expert_Rating_b', 'Price_New_USD', 'Bluetooth Streaming Audio_b','Premium Radio_b', 'Voice Recognition System_b', 'USB Port_b', 'Smartphone Interface_b', 'Internet Access_b', 'Hands Free Phone_b', 'Audible Text Messaging_b', 'Bluetooth Wireless Technology_b', 'MPG', 'number_of_features_b','year','years since new']], KBB_df.depreciation)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
x_train
# Out:
#       const     HP  SafetyRating_4.0  SafetyRating_5.0  SafetyRating_nothing  \
# 67      1.0  106.0                 1                 0                     0
# 1078    1.0  134.0                 1                 0                     0
# 211     1.0  200.0                 0                 0                     1
# 12      1.0  134.0                 1                 0                     0
# 1122    1.0  106.0                 1                 0                     0
# ...     ...    ...               ...               ...                   ...
# 1044    1.0  117.0                 1                 0                     0
# 1095    1.0   99.0                 0                 0                     1
# 1130    1.0  177.0                 0                 0                     1
# 860     1.0   99.0                 0                 0                     1
# 1126    1.0  140.0                 0                 0                     1
#
# ...

# %%
x.columns
#switch price_used with price_new
# Out:
# Index(['HP', 'SafetyRating_4.0', 'SafetyRating_5.0', 'SafetyRating_nothing',
#        'Consumer_Rating', 'Expert_Rating_b', 'Price_New_USD',
#        'Bluetooth Streaming Audio_b', 'Premium Radio_b',
#        'Voice Recognition System_b', 'USB Port_b', 'Smartphone Interface_b',
#        'Internet Access_b', 'Hands Free Phone_b', 'Audible Text Messaging_b',
#        'Bluetooth Wireless Technology_b', 'MPG', 'number_of_features_b',
#        'year', 'years since new'],
#       dtype='object')

# %%
print(reg.coef_, reg.intercept_)
# Out:
# [-9.17621043e-04 -2.91435687e-02  3.88199437e-02 -9.67637504e-03
#  -1.34402060e-01  9.98873507e-03  1.33963018e-07 -1.41586319e-02
#   2.28072289e-02 -3.81666368e-02 -4.48477320e-03  8.67998286e-02
#   1.91726029e-01 -3.26521262e-02 -1.63303905e-01 -3.46268436e-02
#   7.51588332e-04  1.39401697e-02 -6.35259781e-03  6.35259781e-03] 13.899811261384615

# %%
x = KBB_df3[['HP', 'SafetyRating_4.0','SafetyRating_5.0','SafetyRating_nothing', 'Consumer_Rating', 'Expert_Rating_b', 'Price_New_USD', 'Bluetooth Streaming Audio_b','Premium Radio_b', 'Voice Recognition System_b', 'USB Port_b', 'Smartphone Interface_b', 'Internet Access_b', 'Hands Free Phone_b', 'Audible Text Messaging_b', 'Bluetooth Wireless Technology_b', 'MPG', 'number_of_features_b','year','years since new']]
y = KBB_df3['depreciation']

# %%
len(y)
# Out:
# 1179

# %%
x=sm.add_constant(x)

# %%
model = sm.OLS(y, x).fit()

# %%
predictions = model.predict(x)

# %%
print_model = model.summary()
print(print_model) # Null hypothesis is rejected because of the p-value , which means none of these idiviudal features is a good predictor on its own, but together they are more significant as a predictors for depreciation
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           depreciation   R-squared:                       0.230
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     20.36
# Date:                Sun, 03 Jan 2021   Prob (F-statistic):           1.15e-54
# Time:                        12:19:50   Log-Likelihood:                 433.56
# No. Observations:                1179   AIC:                            -831.1
# Df Residuals:                    1161   BIC:                            -739.8
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
#AIC:                            -831.1
#Df Residuals:                    1161   BIC:                            -739.8

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.model_selection import train_test_split

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = linear_regression.predict(x)
print(predictions)
# Out:
# [0.4089277  0.50408735 0.46216819 ... 0.35723478 0.40671295 0.40312063]

# %%
linear_regression.score(x,y)
# Out:
# 0.22963230774793478

# %%
linear_regression.coef_
# Out:
# array([ 0.00000000e+00, -9.17621043e-04, -2.91435687e-02,  3.88199437e-02,
#        -9.67637504e-03, -1.34402060e-01,  9.98873507e-03,  1.33963018e-07,
#        -1.41586319e-02,  2.28072289e-02, -3.81666368e-02, -4.48477320e-03,
#         8.67998286e-02,  1.91726029e-01, -3.26521262e-02, -1.63303905e-01,
#        -3.46268436e-02,  7.51588332e-04,  1.39401697e-02, -6.35259781e-03,
#         6.35259781e-03])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(
x, y, test_size=0.25, random_state=42)

# %%
x_test.columns
# Out:
# Index(['const', 'HP', 'SafetyRating_4.0', 'SafetyRating_5.0',
#        'SafetyRating_nothing', 'Consumer_Rating', 'Expert_Rating_b',
#        'Price_New_USD', 'Bluetooth Streaming Audio_b', 'Premium Radio_b',
#        'Voice Recognition System_b', 'USB Port_b', 'Smartphone Interface_b',
#        'Internet Access_b', 'Hands Free Phone_b', 'Audible Text Messaging_b',
#        'Bluetooth Wireless Technology_b', 'MPG', 'number_of_features_b',
#        'year', 'years since new'],
#       dtype='object')

# %%
x_train.columns
# Out:
# Index(['const', 'HP', 'SafetyRating_4.0', 'SafetyRating_5.0',
#        'SafetyRating_nothing', 'Consumer_Rating', 'Expert_Rating_b',
#        'Price_New_USD', 'Bluetooth Streaming Audio_b', 'Premium Radio_b',
#        'Voice Recognition System_b', 'USB Port_b', 'Smartphone Interface_b',
#        'Internet Access_b', 'Hands Free Phone_b', 'Audible Text Messaging_b',
#        'Bluetooth Wireless Technology_b', 'MPG', 'number_of_features_b',
#        'year', 'years since new'],
#       dtype='object')

# %%
lm = linear_model.LinearRegression()
model = lm.fit(x_train,y_train)

# %%
predictions = lm.predict(x_test)
print(predictions)
# Out:
# [0.54922136 0.51090489 0.44066684 0.51438931 0.39300699 0.52871352
#  0.42708029 0.54197138 0.39655822 0.52135941 0.43834061 0.67984574
#  0.50652233 0.42708029 0.43834061 0.44066684 0.3529901  0.70613701
#  0.54197138 0.37422547 0.54922136 0.67093229 0.52960842 0.39655822
#  0.43834061 0.42700546 0.44066684 0.39655822 0.50792911 0.66550241
#  0.67922592 0.52135941 0.41626447 0.54197138 0.53621827 0.5302272
#  0.39655822 0.51736495 0.63830403 0.52135941 0.54197138 0.39655822
#  0.67494227 0.7186214  0.43834061 0.39655822 0.39655822 0.47221912
#  0.53985051 0.67922592 0.37422547 0.42700546 0.37422547 0.43834061
#  0.51438931 0.74060816 0.51438931 0.44066684 0.6910363  0.4417191
#  0.43834061 0.4417191  0.74060816 0.47221912 0.52135941 0.72984741
#  0.33470007 0.67922592 0.54922136 0.50652233 0.39655822 0.70398568
#  0.37422547 0.61054733 0.51438931 0.44066684 0.40164885 0.662028
#  0.53621827 0.46211404 0.50652233 0.39655822 0.41626447 0.54197138
# ...

# %%
lm.intercept_
# Out:
# 13.239679321832512

# %%
from sklearn.metrics import explained_variance_score
explained_variance_score(y_test, predictions) # for the test data 
#this r 2 while sklearn
# Out:
# 0.28033614324019096

# %%
predictions = model.predict(x)

# %%
predictions2 = model.predict(x_test)

# %%
y_pred = model.predict()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-122-303d4bc229af> in <module>
# ----> 1 y_pred = model.predict(y)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     205         check_is_fitted(self)
#     206
# --> 207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
#     209                                dense_output=True) + self.intercept_
#
# ...

# %%
lm.score(x,y)
# Out:
# 0.22123179723712594

# %%
explained_variance_score(y_train, lm.predict(x_train)) #prediction based on training data which close to the test data
# Out:
# 0.20285597923425425

# %%
explained_variance_score(y, linear_regression.predict(x))
# Out:
# 0.22963230774793475

# %% [markdown]
# # Residuals

# %%
#Residual Sum-of-Squares
print(np.sum((y - lm.predict(x)) ** 2))
# Out:
# 33.44569260534647

# %%
print(y_test-lm.predict(x_test))
# Out:
# 210     0.101226
# 58      0.364430
# 671    -0.019775
# 582    -0.068021
# 218     0.247729
#           ...
# 1039   -0.153395
# 1175   -0.389839
# 622    -0.088136
# 788    -0.012845
# 66      0.336060
# Name: depreciation, Length: 295, dtype: float64

# %%
plt.scatter(y_test,y_test-best_gb.predict(x_test))

# %%
plt.scatter(y_train,y_train-best_gb.predict(x_train))

# %%
#Explained Sum-of-Squares
print(np.sum(lm.predict(x) - np.mean(y)) ** 2)
# Out:
# 3.833612106328697

# %%
residuals = y_test-predictions2

# %%
print_model.resid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-141-c76a36d37ea4> in <module>
# ----> 1 print_model.resid()
#
# AttributeError: 'Summary' object has no attribute 'resid'

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn

# %%
sns.regplot(model.fittedvalues, model.resid, ax = ax)
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# Using multiple linear regression both with statsmodel as well as sklearn produced similar results 0.748,
# .749  is statistically significant but it shows it is not one single characterstic which ultimately
# explains why a car retains its value but the combination

# %% [markdown]
# # Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
gsc = GridSearchCV(
        estimator=RandomForestRegressor(),
        param_grid={
            #'max_features': [.1, .2, .3, ],
            'max_depth': [5,10, 20, 30],
            'n_estimators': [10, 50, 100, 300, 500]
        },
    
        cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)

grid_result = gsc.fit(x_train, y_train)
best_params = grid_result.best_params_
#best_svr = SVR(kernel='rbf', max_features=best_params["max_features"], max_depth=best_params["max_depth"], max_n_estimators=best_params["max_n_estimators"],
                   #coef0=0.1, shrinking=True,
                   #tol=0.001, cache_size=200, verbose=False, max_iter=-1)

# %%
print(best_params)
#max depth how deep it goes 
#n estimators how trees within the forest
# Out:
# {'max_depth': 10, 'n_estimators': 50}

# %%
best_rf = RandomForestRegressor(max_depth= 10, n_estimators= 50)

# %%
modelrf = RandomForestRegressor(max_depth= 20, n_estimators= 50)
# Train the model on training data
modelrf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=20, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
#TESTING THE MODEL BY PREDICTING ON TEST DATA
#AND CALCULATE THE ACCURACY SCORE

prediction_test = modelrf.predict(x_test)
print(y_test, prediction_test)

#from sklearn import metrics
#Print the prediction accuracy
#print ("Accuracy = ", metrics.accuracy_score(y_test, prediction_test))
#Test accuracy for various test sizes and see how it gets better with more training data
# Out:
# 210     0.650448
# 58      0.875335
# 671     0.420892
# 582     0.446369
# 218     0.640736
#           ...
# 1039    0.284946
# 1175    0.025292
# 622     0.433223
# 788     0.383714
# 66      0.867564
# Name: depreciation, Length: 295, dtype: float64 [0.54907919 0.52126395 0.42755632 0.48127793 0.40986386 0.35600705
#  0.43975221 0.51800494 0.39359898 0.42844225 0.31734222 0.66279714
#  0.48755843 0.43975221 0.31734222 0.42755632 0.47312033 0.72286862
#  0.51800494 0.33093446 0.54907919 0.7246817  0.49845036 0.39359898
#  0.31734222 0.39590405 0.42755632 0.39359898 0.4534271  0.77415839
#  0.77675353 0.42844225 0.7221908  0.51800494 0.58921974 0.5519064
#  0.39359898 0.25110442 0.58505669 0.42844225 0.51800494 0.39359898
#  0.82579361 0.56987961 0.31734222 0.39359898 0.39359898 0.46414385
#  0.79172315 0.77675353 0.33093446 0.39590405 0.33093446 0.31734222
#  0.48127793 0.76686245 0.48127793 0.42755632 0.80146945 0.40157978
# ...

# %%
from sklearn.metrics import mean_squared_error
#Print the prediction accuracy
print ("mean_squared_error = ", mean_squared_error(y_test, prediction_test))
#Test accuracy for various test sizes and see how it gets better with more training data
#One amazing feature of Random forest is that it provides us info on feature importances

# get the r2 
#mean2 squared error
# Out:
# mean_squared_error =  0.01913027119031435

# %%
importances = list(modelrf.feature_importances_)

#Let us print them into a nice format.

feature_list = list(x.columns)
feature_imp = pd.Series(modelrf.feature_importances_,index=feature_list).sort_values(ascending=False)
print(feature_imp)
# Out:
# years since new                    0.335830
# year                               0.188239
# Expert_Rating_b                    0.095044
# Price_New_USD                      0.069200
# MPG                                0.068671
# number_of_features_b               0.062330
# HP                                 0.058301
# Consumer_Rating                    0.050079
# Audible Text Messaging_b           0.021345
# Smartphone Interface_b             0.008481
# Premium Radio_b                    0.007437
# SafetyRating_5.0                   0.006929
# Internet Access_b                  0.006189
# SafetyRating_nothing               0.005571
# Bluetooth Streaming Audio_b        0.004036
# SafetyRating_4.0                   0.003774
# Voice Recognition System_b         0.002950
# Bluetooth Wireless Technology_b    0.002063
# Hands Free Phone_b                 0.001929
# USB Port_b                         0.001601
# const                              0.000000
# dtype: float64

# %%
print(best_rf)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
x_test
# Out:
#       const     HP  SafetyRating_4.0  SafetyRating_5.0  SafetyRating_nothing  \
# 210     1.0  160.0                 0                 0                     1
# 58      1.0  176.0                 0                 1                     0
# 671     1.0  106.0                 1                 0                     0
# 582     1.0  106.0                 0                 0                     1
# 218     1.0  134.0                 1                 0                     0
# ...     ...    ...               ...               ...                   ...
# 1039    1.0  106.0                 1                 0                     0
# 1175    1.0  106.0                 1                 0                     0
# 622     1.0  106.0                 0                 0                     1
# 788     1.0   99.0                 1                 0                     0
# 66      1.0   78.0                 1                 0                     0
#
# ...

# %%
y_pred1=modelrf.predict(x_test)

# %%
print("R2 score",r2_score(y_test,y_pred1))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score 0.4547444640626601
# RMSE 0.13831222357519363

# %%
print(grid_result.best_score_)
#look for better scoring metrics
# Out:
# -0.022082893572278037

# %% [markdown]
# # Ridge regression

# %%
from sklearn.linear_model import Ridge

gsc = GridSearchCV(
        estimator=Ridge(),
        param_grid={
            'alpha': [0.2,.4, .6, .8, 1],
            'solver':['auto','svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
            #'n_estimators': [10, 50, 100, 300, 500]
        },
    
        cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)

grid_result2 = gsc.fit(x, y)
best_params2 = grid_result2.best_params_
#best_svr = SVR(kernel='rbf', max_features=best_params["max_features"], max_depth=best_params["max_depth"], max_n_estimators=best_params["max_n_estimators"],
                   #coef0=0.1, shrinking=True,
                   #tol=0.001, cache_size=200, verbose=False, max_iter=-1)
#creating Scoring parameter: 
#scoring = {'accuracy': make_scorer(accuracy_score),
           #'precision': make_scorer(precision_score),'recall':make_scorer(recall_score)}
    
#replace with ridge regression

# %%
print(best_params2)
#alpha is stats
#solver
# Out:
# {'alpha': 0.4, 'solver': 'saga'}

# %%
#best

# %%
best_ridge = Ridge(alpha= .4, solver= 'saga')

# %%
print(best_ridge)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='saga', tol=0.001)

# %%
modelridge = Ridge(alpha= .4, solver= 'saga')
# Train the model on training data
modelridge.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-151-71d317318056> in <module>
# ----> 1 modelridge = Ridge(alpha= .4, solver= 'saga')
#       2 # Train the model on training data
#       3 modelridge.fit(x_train, y_train)
#
# NameError: name 'Ridge' is not defined

# %%
y_pred1=modelridge.predict(x_test)

# %%
print("R2 score",r2_score(y_test,y_pred1))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score 0.038806534819045724
# RMSE 0.18363942584396886

# %%
R2 score 0.6611685515278103
RMSE 0.10903159809758163

# %%
modelridge.coef_
# Out:
# array([ 0.00000000e+00, -4.90509888e-09, -4.01048819e-10,  2.01553164e-11,
#         3.80893503e-10, -7.56339286e-11,  1.56877994e-10, -3.20733928e-06,
#        -4.28396373e-10, -1.37467773e-10, -3.45809406e-10, -4.07269499e-10,
#        -8.94594632e-11,  8.65608601e-12, -3.82804066e-10, -1.17847670e-10,
#        -4.83272998e-10, -6.73459630e-09, -2.38367116e-09, -6.25559649e-09,
#         6.25559649e-09])

# %%
print(grid_result2.best_score_)
# Out:
# -0.05499793566786261

# %% [markdown]
# # GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import make_scorer

gsc = GridSearchCV(
        estimator=GradientBoostingRegressor(),
        param_grid={
            #'max_features': [.1, .2, .3, ],
            'max_depth': [1,3,5,7],
            'n_estimators': [500, 750, 1000]
        },
    
        cv=5, scoring='neg_mean_squared_error', verbose=0, n_jobs=-1)

grid_result1 = gsc.fit(x, y)
best_params1 = grid_result1.best_params_
#best_svr = SVR(kernel='rbf', max_features=best_params["max_features"], max_depth=best_params["max_depth"], max_n_estimators=best_params["max_n_estimators"],
                   #coef0=0.1, shrinking=True,
                   #tol=0.001, cache_size=200, verbose=False, max_iter=-1)
#creating Scoring parameter: 
#scoring = {'accuracy': make_scorer(accuracy_score),
           #'precision': make_scorer(precision_score),'recall':make_scorer(recall_score)}

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
print(best_params1)
# Out:
# {'max_depth': 1, 'n_estimators': 500}

# %%
best_gb = GradientBoostingRegressor(max_depth = 1, n_estimators= 500)

# %%
best_gb.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=1,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
y_pred2=best_gb.predict(x_test)

# %%
importances = list(best_gb.feature_importances_)

#Let us print them into a nice format.

feature_list = list(x.columns)
feature_imp = pd.Series(best_gb.feature_importances_,index=feature_list).sort_values(ascending=False)
print(feature_imp)
# Out:
# years since new                    0.322412
# year                               0.227471
# number_of_features_b               0.094383
# Price_New_USD                      0.094073
# MPG                                0.082410
# Expert_Rating_b                    0.062189
# Audible Text Messaging_b           0.041779
# Consumer_Rating                    0.038566
# HP                                 0.024445
# Voice Recognition System_b         0.010032
# SafetyRating_4.0                   0.002240
# USB Port_b                         0.000000
# Premium Radio_b                    0.000000
# Bluetooth Streaming Audio_b        0.000000
# Smartphone Interface_b             0.000000
# Internet Access_b                  0.000000
# Hands Free Phone_b                 0.000000
# SafetyRating_nothing               0.000000
# SafetyRating_5.0                   0.000000
# Bluetooth Wireless Technology_b    0.000000
# const                              0.000000
# dtype: float64

# %%
mse= mean_squared_error(y_test,y_pred2)
print("MSE: %.10f" % mse)
#get r2, square root of mean squared error
# Out:
# MSE: 0.0151045058

# %%
mse= mean_squared_error(y_test,y_pred2)
print("MSE: %.10f" % mse)
#get r2, square root of mean squared error
# Out:
# MSE: 0.0151045058

# %%
print("R2 score",r2_score(y_test,y_pred2))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred2)))
# Out:
# R2 score 0.4717238801418525
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-241f3750c6d2> in <module>
#       1 print("R2 score",r2_score(y_test,y_pred2))
# ----> 2 print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred2)))
#
# NameError: name 'mean_squared_error' is not defined

# %%
print(grid_result1.best_score_)
#note this is the best score
#residuals vs actuals 
#re run in google colab and kaggle colab 
#remove outliers in the graphs , showfliers=False
#after bluetooth audio, stated the trend for the other graphs with the features
# Out:
# -0.05702525984280611

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Data-cleaning" data-toc-modified-id="Data-cleaning-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Data cleaning</a></span></li><li><span><a href="#Basic-stats" data-toc-modified-id="Basic-stats-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Basic stats</a></span></li><li><span><a href="#Correlation-Heatmap" data-toc-modified-id="Correlation-Heatmap-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Correlation Heatmap</a></span></li><li><span><a href="#years-since-new-vs-depreciation-graph-and-stats" data-toc-modified-id="years-since-new-vs-depreciation-graph-and-stats-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>years since new vs depreciation graph and stats</a></span></li><li><span><a href="#Original-Price-and-depreciation-per-year" data-toc-modified-id="Original-Price-and-depreciation-per-year-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Original Price and depreciation per year</a></span></li><li><span><a href="#Year-distribution" data-toc-modified-id="Year-distribution-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Year distribution</a></span></li><li><span><a href="#Car-Models" data-toc-modified-id="Car-Models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Car Models</a></span></li><li><span><a href="#horsepower-vs-depreciation" data-toc-modified-id="horsepower-vs-depreciation-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>horsepower vs depreciation</a></span></li><li><span><a href="#Miles-per-gallon-vs-depreciation-boxplot" data-toc-modified-id="Miles-per-gallon-vs-depreciation-boxplot-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Miles per gallon vs depreciation boxplot</a></span></li><li><span><a href="#Number-Of-Features-Graph-and-Stats" data-toc-modified-id="Number-Of-Features-Graph-and-Stats-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Number Of Features Graph and Stats</a></span></li><li><span><a href="#Bluetooth-Wireless-Technology-Graph-and-Stats" data-toc-modified-id="Bluetooth-Wireless-Technology-Graph-and-Stats-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Bluetooth Wireless Technology Graph and Stats</a></span></li><li><span><a href="#Audible-Text-Messaging-Graph-and-Stats" data-toc-modified-id="Audible-Text-Messaging-Graph-and-Stats-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Audible Text Messaging Graph and Stats</a></span></li><li><span><a href="#Hands-Free-Phone-Graph-and-Stats" data-toc-modified-id="Hands-Free-Phone-Graph-and-Stats-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Hands Free Phone Graph and Stats</a></span></li><li><span><a href="#Internet-Access-Graph-and-Stats" data-toc-modified-id="Internet-Access-Graph-and-Stats-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Internet Access Graph and Stats</a></span></li><li><span><a href="#Smartphone-Interface--Graph-and-Stats" data-toc-modified-id="Smartphone-Interface--Graph-and-Stats-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Smartphone Interface  Graph and Stats</a></span></li><li><span><a href="#USB-Port-Graph-and-Stats" data-toc-modified-id="USB-Port-Graph-and-Stats-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>USB Port Graph and Stats</a></span></li><li><span><a href="#Voice-Recognition-System-Graph-and-Stats" data-toc-modified-id="Voice-Recognition-System-Graph-and-Stats-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Voice Recognition System Graph and Stats</a></span></li><li><span><a href="#Premium-Radio-Graph-and-Stats" data-toc-modified-id="Premium-Radio-Graph-and-Stats-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Premium Radio Graph and Stats</a></span></li><li><span><a href="#Bluetooth-Streaming-Audio-Graph-and-Stats" data-toc-modified-id="Bluetooth-Streaming-Audio-Graph-and-Stats-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Bluetooth Streaming Audio Graph and Stats</a></span></li><li><span><a href="#Expert-rating-graph-and-stats" data-toc-modified-id="Expert-rating-graph-and-stats-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Expert rating graph and stats</a></span></li><li><span><a href="#Consumer_Ratings-graph-and-stats" data-toc-modified-id="Consumer_Ratings-graph-and-stats-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Consumer_Ratings graph and stats</a></span></li><li><span><a href="#Creating-dummy-variables-for-saftey-ratings" data-toc-modified-id="Creating-dummy-variables-for-saftey-ratings-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Creating dummy variables for saftey ratings</a></span></li><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>Linear regression</a></span></li><li><span><a href="#Random-Forest-Regression" data-toc-modified-id="Random-Forest-Regression-24"><span class="toc-item-num">24&nbsp;&nbsp;</span>Random Forest Regression</a></span></li><li><span><a href="#Ridge-regression" data-toc-modified-id="Ridge-regression-25"><span class="toc-item-num">25&nbsp;&nbsp;</span>Ridge regression</a></span></li><li><span><a href="#GradientBoostingRegressor" data-toc-modified-id="GradientBoostingRegressor-26"><span class="toc-item-num">26&nbsp;&nbsp;</span>GradientBoostingRegressor</a></span></li></ul></div>
